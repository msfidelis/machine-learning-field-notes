# %% [markdown]
# # Setup do Projeto

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt
import scipy
import itertools
from pmdarima import auto_arima
import statsmodels.api as sm
import warnings
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# ## Carregando os Dados

# %%
df = pd.read_csv("inflacao.csv")

# %%
df.describe()
# Out:
#                ano         mes        ano_mes  ipca_variacao  \
# count   515.000000  515.000000     515.000000     515.000000
# mean   2000.959223    6.489320  200102.411650       5.948214
# std      12.399177    3.450227    1239.904297      10.862122
# min    1980.000000    1.000000  198001.000000      -0.680000
# 25%    1990.000000    3.500000  199009.500000       0.380000
# 50%    2001.000000    6.000000  200106.000000       0.780000
# 75%    2012.000000    9.000000  201202.500000       6.840000
# max    2022.000000   12.000000  202211.000000      82.390000
#
#        ipca_acumulado_ano  ipca_acumulado_doze_meses  ipca15_variacao  \
# count          515.000000                 515.000000       515.000000
# mean            96.495709                 310.089010         0.269767
# std            265.975237                 864.719013         0.392667
# min             -0.160000                   0.000000        -0.730000
# 25%              2.485000                   5.250000         0.000000
# 50%              5.230000                   7.770000         0.050000
# 75%             49.070000                 156.790000         0.485000
# max           2477.150000                6821.310000         3.050000
#
#        ipca15_acumulado_ano  ipca15_acumulado_doze_meses  inpc_variacao  \
# count            515.000000                   515.000000     515.000000
# mean               1.855107                     3.380874       5.937029
# std                2.413151                     3.815471      10.868282
# min                0.000000                     0.000000      -0.600000
# 25%                0.000000                     0.000000       0.385000
# 50%                0.650000                     2.800000       0.820000
# 75%                3.265000                     6.205000       6.755000
# max               11.990000                    17.240000      82.180000
#
#        inpc_acumulado_ano  inpc_acumulado_doze_meses  ipa_variacao  \
# count          515.000000                 515.000000    515.000000
# mean            95.998350                 309.124350      6.172835
# std            263.216087                 850.787432     11.046885
# min              0.060000                   0.000000     -2.420000
# 25%              2.585000                   5.405000      0.265000
# 50%              5.210000                   9.030000      1.360000
# 75%             46.755000                 161.665000      7.315000
# max           2489.110000                6554.520000     82.040000
#
#        ipa_acumulado_ano  ipc_fipe_variacao  ipc_fipe_acumulado_ano  \
# count         515.000000         515.000000              515.000000
# mean           41.392097           5.787243               38.828136
# std            73.768541          10.778574               72.750950
# min            -5.820000          -1.000000               -1.790000
# 25%             2.215000           0.300000                1.995000
# 50%             7.550000           0.740000                4.910000
# 75%            43.015000           6.720000               39.500000
# max           381.830000          79.110000              374.660000
#
#        incc_variacao  incc_acumulado_ano
# count     515.000000          515.000000
# mean        6.107126           41.928485
# std        11.219681           73.801160
# min        -0.500000            0.310000
# 25%         0.360000            2.900000
# 50%         0.880000            6.560000
# 75%         6.030000           45.915000
# max        78.410000          388.770000

# %% [markdown]
# ### Formatando o index para a análise preditiva

# %%
df.index = pd.to_datetime(df['referencia'], format='%Y-%m-%d')

# %%
df.index
# Out:
# DatetimeIndex(['1980-01-01', '1980-02-01', '1980-03-01', '1980-04-01',
#                '1980-05-01', '1980-06-01', '1980-07-01', '1980-08-01',
#                '1980-09-01', '1980-10-01',
#                ...
#                '2022-02-01', '2022-03-01', '2022-04-01', '2022-05-01',
#                '2022-06-01', '2022-07-01', '2022-08-01', '2022-09-01',
#                '2022-10-01', '2022-11-01'],
#               dtype='datetime64[ns]', name='referencia', length=515, freq=None)

# %%
df.head()
# Out:
#            referencia   ano  mes  ano_mes  ipca_variacao  ipca_acumulado_ano  \
# referencia
# 1980-01-01    1980-01  1980    1   198001           6.62                6.62
# 1980-02-01    1980-02  1980    2   198002           4.62               11.54
# 1980-03-01    1980-03  1980    3   198003           6.04               18.27
# 1980-04-01    1980-04  1980    4   198004           5.29               24.53
# 1980-05-01    1980-05  1980    5   198005           5.70               31.63
#
#             ipca_acumulado_doze_meses  ipca15_variacao  ipca15_acumulado_ano  \
# referencia
# 1980-01-01                        0.0              0.0                   0.0
# 1980-02-01                        0.0              0.0                   0.0
# 1980-03-01                        0.0              0.0                   0.0
# 1980-04-01                        0.0              0.0                   0.0
# 1980-05-01                        0.0              0.0                   0.0
#
#             ipca15_acumulado_doze_meses  inpc_variacao  inpc_acumulado_ano  \
# referencia
# 1980-01-01                          0.0           6.56                6.56
# 1980-02-01                          0.0           4.15               10.98
# 1980-03-01                          0.0           5.12               16.67
# 1980-04-01                          0.0           4.85               22.33
# 1980-05-01                          0.0           5.53               29.10
#
#             inpc_acumulado_doze_meses  ipa_variacao  ipa_acumulado_ano  \
# referencia
# 1980-01-01                       0.00          7.31               7.31
# 1980-02-01                       0.00          3.69              11.00
# 1980-03-01                      75.11          6.32              17.32
# 1980-04-01                      77.48          6.69              24.01
# 1980-05-01                      84.06          7.32              31.33
#
#             ipc_fipe_variacao  ipc_fipe_acumulado_ano  incc_variacao  \
# referencia
# 1980-01-01               4.48                    4.48           4.70
# 1980-02-01               3.35                    7.83           9.53
# 1980-03-01               4.34                   12.17          12.80
# 1980-04-01               3.93                   16.10           3.13
# 1980-05-01               6.52                   22.62           4.86
#
#             incc_acumulado_ano  consolidado_ano
# referencia
# 1980-01-01                4.70            False
# 1980-02-01               14.23            False
# 1980-03-01               27.03            False
# 1980-04-01               30.16            False
# 1980-05-01               35.02            False

# %% [markdown]
# ### Pegando uma amostra recente dos dados

# %%
df_analise = df[df['ano'] >= 1995]

# %%
df_analise.shape
# Out:
# (335, 20)

# %%
df_analise = df_analise.ipca_variacao

# %%
df_analise.shape
# Out:
# (335,)

# %% [markdown]
# ### Criando o Dataset de Treino e Teste

# %%
train = df_analise[df_analise.index <= pd.to_datetime("2022-03-01", format='%Y-%m-%d')]
train.index = pd.DatetimeIndex(train.index.values,
                               freq=train.index.inferred_freq)

# %%
train.shape
# Out:
# (327,)

# %%
test = df_analise[df_analise.index >= pd.to_datetime("2022-03-01", format='%Y-%m-%d')]
test.index = pd.DatetimeIndex(test.index.values,
                               freq=test.index.inferred_freq)

# %%
test.shape
# Out:
# (9,)

# %% [markdown]
# ## Análise com o Autoarima

# %% [markdown]
# * Gerando um gráfico para criar uma referencia visual do treino

# %%
plt.figure(figsize=(25, 8))
plt.plot(train, label="IPCA - Treino", color='black')
plt.plot(test, label="IPCA - Teste", color='red')
plt.xlabel("Período de Referencia")
plt.ylabel("Variação do IPCA")


plt.title("Variação do IPCA Split de Treino / Teste")
plt.legend()
plt.show()

# %% [markdown]
# * Encontrando o fit do melhor modelo para ARIMA / SARIMA

# %%
sarima_model = auto_arima(train, start_p=0, start_q=0, start_P=0, start_Q=0, start_D=0,
                     max_p=6, max_q=6, max_P=6, max_Q=6, max_D=6, seasonal=True,
                     stepwise=False, suppress_warnings=True,
                     error_action='ignore', m=12, trace=True)
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=257.120, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=243.941, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=243.819, Time=0.72 sec
#  ARIMA(0,1,0)(0,0,3)[12] intercept   : AIC=242.991, Time=0.91 sec
#  ARIMA(0,1,0)(0,0,4)[12] intercept   : AIC=244.804, Time=1.71 sec
#  ARIMA(0,1,0)(0,0,5)[12] intercept   : AIC=245.737, Time=3.75 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=241.491, Time=0.07 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=237.676, Time=0.22 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=238.561, Time=1.25 sec
#  ARIMA(0,1,0)(1,0,3)[12] intercept   : AIC=240.362, Time=1.78 sec
#  ARIMA(0,1,0)(1,0,4)[12] intercept   : AIC=242.353, Time=6.06 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=241.699, Time=0.23 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=238.658, Time=0.63 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.70 sec
#  ARIMA(0,1,0)(2,0,3)[12] intercept   : AIC=inf, Time=3.25 sec
#  ARIMA(0,1,0)(3,0,0)[12] intercept   : AIC=241.251, Time=0.80 sec
#  ARIMA(0,1,0)(3,0,1)[12] intercept   : AIC=240.387, Time=2.10 sec
#  ARIMA(0,1,0)(3,0,2)[12] intercept   : AIC=inf, Time=3.79 sec
#  ARIMA(0,1,0)(4,0,0)[12] intercept   : AIC=242.793, Time=1.48 sec
#  ARIMA(0,1,0)(4,0,1)[12] intercept   : AIC=242.379, Time=4.46 sec
#  ARIMA(0,1,0)(5,0,0)[12] intercept   : AIC=243.223, Time=3.81 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=246.188, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=234.327, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=234.336, Time=0.91 sec
#  ARIMA(0,1,1)(0,0,3)[12] intercept   : AIC=233.692, Time=1.46 sec
#  ARIMA(0,1,1)(0,0,4)[12] intercept   : AIC=235.248, Time=2.54 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=232.115, Time=0.11 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=228.627, Time=0.34 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=229.714, Time=1.97 sec
#  ARIMA(0,1,1)(1,0,3)[12] intercept   : AIC=231.525, Time=3.58 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=232.360, Time=0.37 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=229.796, Time=0.74 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=2.01 sec
#  ARIMA(0,1,1)(3,0,0)[12] intercept   : AIC=231.914, Time=0.95 sec
#  ARIMA(0,1,1)(3,0,1)[12] intercept   : AIC=231.547, Time=3.15 sec
#  ARIMA(0,1,1)(4,0,0)[12] intercept   : AIC=233.277, Time=2.29 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=217.624, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=207.246, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=208.254, Time=1.25 sec
#  ARIMA(0,1,2)(0,0,3)[12] intercept   : AIC=208.697, Time=1.98 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=205.923, Time=0.17 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=203.275, Time=0.51 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=203.632, Time=1.78 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=207.209, Time=0.76 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=203.793, Time=1.27 sec
#  ARIMA(0,1,2)(3,0,0)[12] intercept   : AIC=207.245, Time=1.76 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=215.793, Time=0.07 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=203.857, Time=0.27 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=204.433, Time=1.21 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=202.036, Time=0.31 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=199.029, Time=0.75 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=202.980, Time=0.77 sec
#  ARIMA(0,1,4)(0,0,0)[12] intercept   : AIC=214.916, Time=0.15 sec
#  ARIMA(0,1,4)(0,0,1)[12] intercept   : AIC=203.795, Time=0.54 sec
#  ARIMA(0,1,4)(1,0,0)[12] intercept   : AIC=202.081, Time=0.47 sec
#  ARIMA(0,1,5)(0,0,0)[12] intercept   : AIC=213.920, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=252.313, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=239.846, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=239.642, Time=0.79 sec
#  ARIMA(1,1,0)(0,0,3)[12] intercept   : AIC=238.692, Time=1.18 sec
#  ARIMA(1,1,0)(0,0,4)[12] intercept   : AIC=240.451, Time=1.95 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=237.424, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=233.664, Time=0.23 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=234.775, Time=1.66 sec
#  ARIMA(1,1,0)(1,0,3)[12] intercept   : AIC=236.611, Time=2.80 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=237.467, Time=0.39 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=234.849, Time=0.86 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.85 sec
#  ARIMA(1,1,0)(3,0,0)[12] intercept   : AIC=236.969, Time=1.04 sec
#  ARIMA(1,1,0)(3,0,1)[12] intercept   : AIC=236.639, Time=2.87 sec
#  ARIMA(1,1,0)(4,0,0)[12] intercept   : AIC=238.535, Time=3.57 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=214.243, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=201.208, Time=0.37 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=201.409, Time=1.36 sec
#  ARIMA(1,1,1)(0,0,3)[12] intercept   : AIC=200.970, Time=2.45 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=198.991, Time=0.38 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=197.215, Time=0.76 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=198.484, Time=2.38 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=199.735, Time=1.06 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=200.908, Time=1.56 sec
#  ARIMA(1,1,1)(3,0,0)[12] intercept   : AIC=199.894, Time=4.25 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=213.441, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=200.989, Time=0.48 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=201.445, Time=1.63 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=199.029, Time=0.43 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=196.960, Time=0.67 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=199.928, Time=1.03 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=214.627, Time=0.22 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=202.233, Time=0.69 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=200.387, Time=0.61 sec
#  ARIMA(1,1,4)(0,0,0)[12] intercept   : AIC=215.589, Time=0.25 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=235.142, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=223.971, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=224.798, Time=0.88 sec
#  ARIMA(2,1,0)(0,0,3)[12] intercept   : AIC=225.242, Time=1.18 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=222.443, Time=0.14 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=219.785, Time=0.43 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=220.215, Time=1.65 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=223.600, Time=0.45 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=220.400, Time=1.29 sec
#  ARIMA(2,1,0)(3,0,0)[12] intercept   : AIC=223.562, Time=1.03 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=214.193, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=201.498, Time=0.28 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=201.849, Time=1.58 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=199.436, Time=0.46 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=198.208, Time=0.55 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=200.247, Time=1.28 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=214.443, Time=0.14 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=202.425, Time=0.46 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=200.587, Time=0.63 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=216.523, Time=0.27 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=235.903, Time=0.03 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=222.758, Time=0.13 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=223.307, Time=1.00 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=220.761, Time=0.17 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=216.972, Time=0.45 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=221.789, Time=0.69 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=215.015, Time=0.18 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=202.234, Time=0.44 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=200.352, Time=0.64 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=216.035, Time=0.21 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=233.119, Time=0.07 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=220.823, Time=0.12 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=219.090, Time=0.20 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=213.891, Time=0.19 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=227.864, Time=0.08 sec
#
# Best model:  ARIMA(1,1,2)(1,0,1)[12] intercept
# Total fit time: 132.127 seconds

# %% [markdown]
# * Visualizado os dados do modelo gerado

# %%
sarima_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  327
# Model:             SARIMAX(1, 1, 2)x(1, 0, [1], 12)   Log Likelihood                 -91.480
# Date:                              Tue, 27 Dec 2022   AIC                            196.960
# Time:                                      18:03:35   BIC                            223.468
# Sample:                                  01-01-1995   HQIC                           207.538
#                                        - 03-01-2022
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -0.0002      0.001     -0.301      0.763      -0.002       0.001
# ar.L1          0.4333      0.109      3.962      0.000       0.219       0.648
# ma.L1         -0.6995      0.120     -5.818      0.000      -0.935      -0.464
# ma.L2         -0.1564      0.081     -1.939      0.053      -0.315       0.002
# ar.S.L12       0.8514      0.100      8.541      0.000       0.656       1.047
# ma.S.L12      -0.6983      0.129     -5.409      0.000      -0.951      -0.445
# sigma2         0.1010      0.005     22.061      0.000       0.092       0.110
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               386.77
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.56   Skew:                             0.75
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# * Diagnósticos do modelo

# %%
sarima_model.plot_diagnostics(figsize=(14,10))
plt.show()

# %% [markdown]
# ### Criando um modelo com o fit previsto, utilizando a biblioteca do Sarima

# %%
SARIMAXmodel = SARIMAX(train, order = (1,1,2), seasonal_order=(1,0,1, 12), enforce_stationarity=True, enforce_invertibility=True)
SARIMAXmodel = SARIMAXmodel.fit()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.02753D-01    |proj g|=  6.78613D-02
#
# At iterate    5    f=  2.95680D-01    |proj g|=  4.54188D-02
#
# At iterate   10    f=  2.85407D-01    |proj g|=  2.40175D-01
#
# At iterate   15    f=  2.82291D-01    |proj g|=  4.05681D-03
#
# At iterate   20    f=  2.80952D-01    |proj g|=  1.97808D-02
#
# At iterate   25    f=  2.79892D-01    |proj g|=  2.84453D-03
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     29     34      1     0     0   2.131D-06   2.798D-01
#   F =  0.27984628273172152
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %% [markdown]
# * Colocando a o teste no gráfico para visualização

# %%
y_pred = SARIMAXmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05) 
y_pred_df["Predictions"] = SARIMAXmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index

y_pred_out_sarima = y_pred_df["Predictions"]

# %%
plt.figure(figsize=(25, 8))
plt.plot(train.index, train, label="IPCA - Treino", color='black')
plt.plot(test.index, test, label="IPCA - Teste", color='red')

plt.plot(y_pred_out_sarima, color='Blue', label = 'IPCA Predictions SARIMA')

plt.xlabel("Período de Referencia")
plt.ylabel("Variação do IPCA")

plt.title("Variação do IPCA Split de Treino / Teste")
plt.legend()
plt.show()

# %% [markdown]
# ### Comparando com o modelo direto do Autosarima

# %%
prediction, confint = sarima_model.predict(n_periods=len(test.index), return_conf_int=True)
prediction
# Out:
# 2022-04-01    1.233756
# 2022-05-01    1.080952
# 2022-06-01    1.013200
# 2022-07-01    1.029216
# 2022-08-01    0.950682
# 2022-09-01    1.050942
# 2022-10-01    1.113182
# 2022-11-01    1.062139
# 2022-12-01    1.157481
# Freq: MS, dtype: float64

# %%
prediction_series = pd.Series(prediction,index=test.index)

# %%
plt.figure(figsize=(25, 8))
plt.plot(train.index, train, label="IPCA - Treino", color='black')
plt.plot(test.index, test, label="IPCA - Teste", color='red')

plt.plot(y_pred_out_sarima, color='Blue', label = 'IPCA Predictions SARIMA')
plt.plot(prediction_series, color='Green', label = 'IPCA Predictions AUTOARIMA')

plt.xlabel("Período de Referencia")
plt.ylabel("Variação do IPCA")

plt.title("Variação do IPCA Split de Treino / Teste")
plt.legend()
plt.show()

# %%
prediction_sarimax = SARIMAXmodel.predict(start='2022-11-01',end='2024-12-01')

# %%
prediction_sarimax
# Out:
# 2022-11-01    1.080931
# 2022-12-01    1.178816
# 2023-01-01    0.975553
# 2023-02-01    1.114246
# 2023-03-01    1.200279
# 2023-04-01    1.034911
# 2023-05-01    1.048704
# 2023-06-01    1.053756
# 2023-07-01    1.095404
# 2023-08-01    1.040443
# 2023-09-01    1.133067
# 2023-10-01    1.190177
# 2023-11-01    1.148382
# 2023-12-01    1.232432
# 2024-01-01    1.059087
# 2024-02-01    1.177601
# 2024-03-01    1.251101
# 2024-04-01    1.109922
# 2024-05-01    1.121706
# 2024-06-01    1.126024
# 2024-07-01    1.161586
# 2024-08-01    1.114659
# 2024-09-01    1.193745
# 2024-10-01    1.242508
# 2024-11-01    1.206822
# 2024-12-01    1.278586
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(25, 8))
plt.plot(train.index, train, label="IPCA - Treino", color='black')
plt.plot(test.index, test, label="IPCA - Teste", color='red')

plt.plot(y_pred_out_sarima, color='Blue', label = 'IPCA Predictions SARIMA')
plt.plot(prediction_series, color='Green', label = 'IPCA Predictions AUTOARIMA')

plt.plot(prediction_sarimax, color='Purple', label = 'IPCA Predictions Sarima - Real')

plt.xlabel("Período de Referencia")
plt.ylabel("Variação do IPCA")

plt.title("Variação do IPCA Split de Treino / Teste")
plt.legend()
plt.show()

# %%
cf= pd.DataFrame(confint)

# %%
cf
# Out:
#           0         1
# 0  0.610873  1.856639
# 1  0.308350  1.853554
# 2  0.188729  1.837671
# 3  0.177307  1.881125
# 4  0.079406  1.821959
# 5  0.163443  1.938440
# 6  0.210850  2.015515
# 7  0.145668  1.978610
# 8  0.227280  2.087683

# %%
plt.figure(figsize=(25, 8))
plt.plot(train.index, train, label="IPCA - Treino", color='black')
plt.plot(test.index, test, label="IPCA - Teste", color='red')

plt.plot(y_pred_out_sarima, color='Blue', label = 'IPCA Predictions SARIMA')
plt.plot(prediction_series, color='Green', label = 'IPCA Predictions AUTOARIMA')

plt.plot(prediction_sarimax, color='Purple', label = 'IPCA Predictions Sarima - Real')


plt.xlabel("Período de Referencia")
plt.ylabel("Variação do IPCA")

plt.title("Variação do IPCA Split de Treino / Teste")
plt.legend()
plt.show()

# %% [markdown]
# ## Realizando o treino com todos os dados

# %% [markdown]
# * Utilizando o autoarima mas com todos os dados da amostra, ou seja, treino + teste

# %%
sarima_model_analise = auto_arima(df_analise, start_p=0, start_q=0, start_P=0, start_Q=0, start_D=0,
                     max_p=6, max_q=6, max_P=6, max_Q=6, max_D=6, seasonal=True,
                     stepwise=False, suppress_warnings=True,
                     error_action='ignore', m=12, trace=True)
# Out:
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=281.788, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=271.591, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,2)[12] intercept   : AIC=271.178, Time=0.50 sec
#  ARIMA(0,1,0)(0,0,3)[12] intercept   : AIC=271.000, Time=0.88 sec
#  ARIMA(0,1,0)(0,0,4)[12] intercept   : AIC=271.402, Time=2.28 sec
#  ARIMA(0,1,0)(0,0,5)[12] intercept   : AIC=272.955, Time=2.97 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=269.374, Time=0.07 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=263.588, Time=0.17 sec
#  ARIMA(0,1,0)(1,0,2)[12] intercept   : AIC=265.147, Time=1.05 sec
#  ARIMA(0,1,0)(1,0,3)[12] intercept   : AIC=266.916, Time=2.41 sec
#  ARIMA(0,1,0)(1,0,4)[12] intercept   : AIC=268.730, Time=4.09 sec
#  ARIMA(0,1,0)(2,0,0)[12] intercept   : AIC=269.023, Time=0.28 sec
#  ARIMA(0,1,0)(2,0,1)[12] intercept   : AIC=265.185, Time=0.76 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=1.68 sec
#  ARIMA(0,1,0)(2,0,3)[12] intercept   : AIC=inf, Time=3.38 sec
#  ARIMA(0,1,0)(3,0,0)[12] intercept   : AIC=268.565, Time=0.66 sec
#  ARIMA(0,1,0)(3,0,1)[12] intercept   : AIC=266.902, Time=1.64 sec
#  ARIMA(0,1,0)(3,0,2)[12] intercept   : AIC=inf, Time=3.54 sec
#  ARIMA(0,1,0)(4,0,0)[12] intercept   : AIC=268.897, Time=1.56 sec
#  ARIMA(0,1,0)(4,0,1)[12] intercept   : AIC=268.820, Time=4.29 sec
#  ARIMA(0,1,0)(5,0,0)[12] intercept   : AIC=270.380, Time=2.90 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=269.971, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=260.499, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=260.527, Time=0.82 sec
#  ARIMA(0,1,1)(0,0,3)[12] intercept   : AIC=260.024, Time=1.36 sec
#  ARIMA(0,1,1)(0,0,4)[12] intercept   : AIC=260.581, Time=2.27 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=258.563, Time=0.10 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=253.193, Time=0.25 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=254.652, Time=1.65 sec
#  ARIMA(0,1,1)(1,0,3)[12] intercept   : AIC=256.393, Time=3.08 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=258.527, Time=0.30 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=254.702, Time=0.87 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=inf, Time=1.87 sec
#  ARIMA(0,1,1)(3,0,0)[12] intercept   : AIC=257.726, Time=1.14 sec
#  ARIMA(0,1,1)(3,0,1)[12] intercept   : AIC=256.393, Time=2.66 sec
#  ARIMA(0,1,1)(4,0,0)[12] intercept   : AIC=258.245, Time=2.01 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=243.769, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=236.949, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=238.054, Time=1.08 sec
#  ARIMA(0,1,2)(0,0,3)[12] intercept   : AIC=238.552, Time=1.81 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=235.942, Time=0.54 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=230.779, Time=0.67 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=232.161, Time=2.51 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=237.054, Time=0.64 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=232.241, Time=2.05 sec
#  ARIMA(0,1,2)(3,0,0)[12] intercept   : AIC=236.729, Time=1.82 sec
#  ARIMA(0,1,3)(0,0,0)[12] intercept   : AIC=240.143, Time=0.11 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=231.658, Time=0.40 sec
#  ARIMA(0,1,3)(0,0,2)[12] intercept   : AIC=232.177, Time=1.10 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=230.125, Time=0.22 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=224.658, Time=0.85 sec
#  ARIMA(0,1,3)(2,0,0)[12] intercept   : AIC=230.695, Time=1.19 sec
#  ARIMA(0,1,4)(0,0,0)[12] intercept   : AIC=238.296, Time=0.13 sec
#  ARIMA(0,1,4)(0,0,1)[12] intercept   : AIC=230.530, Time=0.45 sec
#  ARIMA(0,1,4)(1,0,0)[12] intercept   : AIC=229.059, Time=0.36 sec
#  ARIMA(0,1,5)(0,0,0)[12] intercept   : AIC=236.374, Time=0.25 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=275.937, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=265.971, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=265.607, Time=0.78 sec
#  ARIMA(1,1,0)(0,0,3)[12] intercept   : AIC=265.055, Time=1.23 sec
#  ARIMA(1,1,0)(0,0,4)[12] intercept   : AIC=265.683, Time=2.44 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=263.781, Time=0.15 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=258.177, Time=0.27 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=259.736, Time=1.24 sec
#  ARIMA(1,1,0)(1,0,3)[12] intercept   : AIC=261.537, Time=3.50 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=263.384, Time=0.66 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=259.772, Time=0.84 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=inf, Time=2.23 sec
#  ARIMA(1,1,0)(3,0,0)[12] intercept   : AIC=262.694, Time=1.02 sec
#  ARIMA(1,1,0)(3,0,1)[12] intercept   : AIC=261.537, Time=2.24 sec
#  ARIMA(1,1,0)(4,0,0)[12] intercept   : AIC=263.322, Time=1.94 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=235.162, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(1,1,1)(0,0,3)[12] intercept   : AIC=inf, Time=4.15 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=inf, Time=2.86 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=1.33 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=1.64 sec
#  ARIMA(1,1,1)(3,0,0)[12] intercept   : AIC=223.384, Time=3.22 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=236.030, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=225.595, Time=0.60 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=226.679, Time=1.96 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=222.197, Time=0.55 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=224.945, Time=1.33 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=237.340, Time=0.22 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=226.877, Time=0.70 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(1,1,4)(0,0,0)[12] intercept   : AIC=238.347, Time=0.28 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=261.793, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=253.975, Time=0.08 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=254.804, Time=0.88 sec
#  ARIMA(2,1,0)(0,0,3)[12] intercept   : AIC=255.158, Time=1.50 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=252.709, Time=0.14 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=247.771, Time=0.41 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=249.157, Time=1.90 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=253.532, Time=0.59 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=249.232, Time=1.53 sec
#  ARIMA(2,1,0)(3,0,0)[12] intercept   : AIC=253.095, Time=1.20 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=236.272, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=221.213, Time=0.61 sec
#  ARIMA(2,1,1)(2,0,0)[12] intercept   : AIC=inf, Time=1.55 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=237.281, Time=0.17 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=239.262, Time=0.30 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=261.954, Time=0.03 sec
#  ARIMA(3,1,0)(0,0,1)[12] intercept   : AIC=251.974, Time=0.16 sec
#  ARIMA(3,1,0)(0,0,2)[12] intercept   : AIC=252.496, Time=0.91 sec
#  ARIMA(3,1,0)(1,0,0)[12] intercept   : AIC=250.202, Time=0.15 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=243.796, Time=0.39 sec
#  ARIMA(3,1,0)(2,0,0)[12] intercept   : AIC=250.827, Time=0.56 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=238.749, Time=0.26 sec
#  ARIMA(4,1,0)(0,0,0)[12] intercept   : AIC=258.868, Time=0.04 sec
#  ARIMA(4,1,0)(0,0,1)[12] intercept   : AIC=249.613, Time=0.12 sec
#  ARIMA(4,1,0)(1,0,0)[12] intercept   : AIC=247.945, Time=0.24 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=237.240, Time=0.27 sec
#  ARIMA(5,1,0)(0,0,0)[12] intercept   : AIC=251.534, Time=0.05 sec
#
# Best model:  ARIMA(2,1,1)(1,0,1)[12] intercept
# Total fit time: 133.235 seconds

# %%
analise_model = SARIMAX(df_analise, order = (2,1,1), seasonal_order=(1,0,1, 12), enforce_stationarity=True, enforce_invertibility=True)
analise_model = analise_model.fit()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.54453D-01    |proj g|=  6.94708D-02
#
# At iterate    5    f=  3.49055D-01    |proj g|=  7.29483D-02
#
# At iterate   10    f=  3.19225D-01    |proj g|=  8.32656D-02
#
# At iterate   15    f=  3.11544D-01    |proj g|=  1.52840D-02
#
# At iterate   20    f=  3.10299D-01    |proj g|=  1.51497D-02
#
# At iterate   25    f=  3.10235D-01    |proj g|=  2.27614D-03
#
# At iterate   30    f=  3.09777D-01    |proj g|=  4.57190D-02
#
# At iterate   35    f=  3.09572D-01    |proj g|=  5.37104D-03
#
# At iterate   40    f=  3.09565D-01    |proj g|=  4.42089D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     40     46      1     0     0   4.421D-06   3.096D-01
#   F =  0.30956539311530690
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL

# %% [markdown]
# * Realizando a previsão dos proximos valores

# %%
prediction_analise = analise_model.predict(start='2022-12-01',end='2024-12-01')

# %%
prediction_analise
# Out:
# 2022-12-01    0.564150
# 2023-01-01    0.391415
# 2023-02-01    0.549696
# 2023-03-01    0.645834
# 2023-04-01    0.461755
# 2023-05-01    0.416190
# 2023-06-01    0.466484
# 2023-07-01    0.306011
# 2023-08-01    0.309543
# 2023-09-01    0.405303
# 2023-10-01    0.591917
# 2023-11-01    0.530609
# 2023-12-01    0.633831
# 2024-01-01    0.459464
# 2024-02-01    0.582747
# 2024-03-01    0.655973
# 2024-04-01    0.485986
# 2024-05-01    0.440172
# 2024-06-01    0.480335
# 2024-07-01    0.336277
# 2024-08-01    0.337322
# 2024-09-01    0.420091
# 2024-10-01    0.583201
# 2024-11-01    0.528530
# 2024-12-01    0.618801
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(25, 8))
plt.plot(df_analise, label="IPCA - Calculado", color='black')
plt.plot(prediction_analise, label="IPCA - Previsão", color='red')


plt.xlabel("Período de Referencia")
plt.ylabel("Variação do IPCA")

plt.title("Variação do IPCA com Previsão")
plt.legend()
plt.show()
